# %% [markdown]
# <a href="https://colab.research.google.com/github/PattuSri/workspace/blob/main/PattuSubhaLakshmi_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
fl=pd.read_csv("/content/drive/MyDrive/Assignment-1_Data.csv",delimiter=';')
fl
# Out:
#         BillNo                             Itemname  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 522059  581587          PACK OF 20 SPACEBOY NAPKINS        12
# 522060  581587          CHILDREN'S APRON DOLLY GIRL         6
# 522061  581587         CHILDRENS CUTLERY DOLLY GIRL         4
# 522062  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 522063  581587         BAKING SET 9 PIECE RETROSPOT         3
#
#                     Date Price  CustomerID         Country
# 0       01.12.2010 08:26  2,55     17850.0  United Kingdom
# 1       01.12.2010 08:26  3,39     17850.0  United Kingdom
# ...

# %%
#Items bought more
max= fl.groupby("Itemname")["Quantity"].transform("sum")
fl.loc[max.idxmax()]["Itemname"]
# Out:
# 'PAPER CRAFT , LITTLE BIRDIE'

# %%
#customer who buys more
fl.loc[fl.groupby("CustomerID")["Quantity"].transform("sum").idxmax()][["CustomerID"]]
# Out:
# CustomerID    14646.0
# Name: 36881, dtype: object

# %%
#customer who buys for more price
#fl['Price'] = fl['Price'].str.replace(',', '').astype(float)
fl.loc[fl.groupby("CustomerID")["Price"].transform("sum").idxmax()]["CustomerID"]
fl.groupby("CustomerID")["Price"].sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-845d8ace03db> in <cell line: 2>()
#       1 #customer who buys for more price
# ----> 2 fl['Price'] = fl['Price'].str.replace(',', '').astype(float)
#       3 fl.loc[fl.groupby("CustomerID")["Price"].transform("sum").idxmax()]["CustomerID"]
#       4 fl.groupby("CustomerID")["Price"].sum().sort_values(ascending=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
#customer bought recently
fl=fl.dropna(subset=["CustomerID"])
fl.sort_values(by=["Date"],ascending=False).head(50)
# Out:
#         BillNo                             Itemname  Quantity  \
# 415017  573695          LANDMARK FRAME NOTTING HILL         2
# 415021  573695       SET OF 2 TRAYS HOME SWEET HOME         2
# 415014  573695           LANDMARK FRAME CAMDEN TOWN         2
# 415015  573695         LANDMARK FRAME OXFORD STREET         1
# 415016  573695         LANDMARK FRAME LONDON BRIDGE         2
# 415018  573695         LANDMARK FRAME COVENT GARDEN         2
# 415019  573695          LANDMARK FRAME BAKER STREET         2
# 415020  573695   WHITE HANGING HEART T-LIGHT HOLDER        32
# 415022  573695                   WALL ART KEEP CALM         1
# 415023  573695           FOOT STOOL HOME SWEET HOME         4
# 415013  573695                   RABBIT NIGHT LIGHT         9
# 414981  573665                  PHOTO FRAME CORNICE         4
# 414983  573666         GIANT 50'S CHRISTMAS CRACKER         4
# 414984  573666     CHRISTMAS HANGING TREE WITH BELL        48
# ...

# %%
#customer buys frequently
fl.groupby("CustomerID")["BillNo"].nunique().sort_values(ascending=False)
# Out:
# CustomerID
# 12748.0    210
# 17841.0    124
# 13089.0     97
# 14606.0     93
# 15311.0     91
#           ...
# 13774.0      1
# 16248.0      1
# 16247.0      1
# 13778.0      1
# 12346.0      1
# Name: BillNo, Length: 4297, dtype: int64

# %% [markdown]
# **bold text**# New Section

# %% [markdown]
# *italicized text*# New Section
